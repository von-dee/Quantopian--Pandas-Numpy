# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
returns = pd.DataFrame(np.random.normal(1.0, 0.03, (100, 10)))
prices = returns.cumprod()
prices.plot()
plt.title('Randomly-generated Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc=0);

# %%
#Pandas Data Structure

# %%
s = pd.Series([1, 2, np.nan, 4, 5])
print (s)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# dtype: float64

# %%
#Name series

# %%
print (s.name)
# Out:
# None

# %%
s.name = "Toy Series"
print (s.name)
# Out:
# Toy Series

# %%
print (s.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
new_index = pd.date_range("2016-01-01", periods=len(s), freq="D")
print (new_index)
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
start = 0
end = len(s) - 1
step = 1

s.iloc[start:end:step]
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# Name: Toy Series, dtype: float64

# %%
#reverse a series
s.iloc[::-1]
# Out:
# 4    5.0
# 3    4.0
# 2    NaN
# 1    2.0
# 0    1.0
# Name: Toy Series, dtype: float64

# %%
# Indexing and Time series

# %%
symbol = "CMG"
start = "2012-01-01"
end = "2016-01-01"
prices = get_pricing(symbol, start_date=start, end_date=end, fields="price")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-daa1891c3bb9> in <module>()
#       2 start = "2012-01-01"
#       3 end = "2016-01-01"
# ----> 4 prices = get_pricing(symbol, start_date=start, end_date=end, fields="price")
#
# NameError: name 'get_pricing' is not defined

# %%
# Time series

# %%
prices.plot();
# We still need to add the axis labels and title ourselves
plt.title(symbol + " Prices")
plt.ylabel("Price")
plt.xlabel("Date");

# %%
print ("Mean: ", prices.mean())
print ("Standard deviation: ", prices.std())
# Out:
# Mean:  0    1.068149
# 1    0.972588
# 2    1.210605
# 3    1.226951
# 4    0.957909
# 5    1.027321
# 6    1.028074
# 7    0.954247
# 8    1.115119
# 9    0.961563
# dtype: float64
# Standard deviation:  0    0.109280
# 1    0.067839
# 2    0.098831
# 3    0.089143
# 4    0.070440
# 5    0.068959
# 6    0.069184
# 7    0.093446
# 8    0.155011
# 9    0.083160
# dtype: float64

# %%
print ("Summary Statistics")
print (prices.describe())
# Out:
# Summary Statistics
#                 0           1           2           3           4           5  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.068149    0.972588    1.210605    1.226951    0.957909    1.027321
# std      0.109280    0.067839    0.098831    0.089143    0.070440    0.068959
# min      0.886717    0.859913    1.023141    0.983201    0.812055    0.912778
# 25%      0.985024    0.922085    1.151560    1.184463    0.912746    0.970013
# 50%      1.041734    0.965644    1.192423    1.250841    0.958606    1.015975
# 75%      1.122388    1.021697    1.265547    1.276527    1.013779    1.077350
# max      1.330636    1.124166    1.444677    1.416394    1.096492    1.201571
#
#                 6           7           8           9
# count  100.000000  100.000000  100.000000  100.000000
# mean     1.028074    0.954247    1.115119    0.961563
# std      0.069184    0.093446    0.155011    0.083160
# min      0.876929    0.793172    0.888821    0.786242
# 25%      0.974852    0.877845    0.999164    0.899086
# 50%      1.027432    0.930957    1.077102    0.969806
# 75%      1.075404    1.037812    1.239090    1.026350
# max      1.198298    1.162370    1.475985    1.111740

# %%
# Data Frame

# %%
dict_data = {
    'a' : [1, 2, 3, 4, 5],
    'b' : ['L', 'K', 'J', 'M', 'Z'],
    'c' : np.random.normal(0, 1, 5)
}
print (dict_data)
# Out:
# {'b': ['L', 'K', 'J', 'M', 'Z'], 'a': [1, 2, 3, 4, 5], 'c': array([-2.38967523,  0.90195028, -2.04302135, -1.37547204,  0.27611171])}

# %%
frame_data = pd.DataFrame(dict_data, index=pd.date_range('2016-01-01', periods=5))
print (frame_data)
# Out:
#             a  b         c
# 2016-01-01  1  L -2.389675
# 2016-01-02  2  K  0.901950
# 2016-01-03  3  J -2.043021
# 2016-01-04  4  M -1.375472
# 2016-01-05  5  Z  0.276112

# %%
s_1 = pd.Series([2, 4, 6, 8, 10], name='Evens')
s_2 = pd.Series([1, 3, 5, 7, 9], name="Odds")
numbers = pd.concat([s_1, s_2], axis=1)
print (numbers)
# Out:
#    Evens  Odds
# 0      2     1
# 1      4     3
# 2      6     5
# 3      8     7
# 4     10     9

# %%
symbol = ["CMG", "MCD", "SHAK", "WFM"]
start = "2012-01-01"
end = "2016-01-01"
prices = get_pricing(symbol, start_date=start, end_date=end, fields="price")
if isinstance(symbol, list):
    prices.columns = map(lambda x: x.symbol, prices.columns)
else:
    prices.name = symbol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b3304e5b10e1> in <module>()
#       2 start = "2012-01-01"
#       3 end = "2016-01-01"
# ----> 4 prices = get_pricing(symbol, start_date=start, end_date=end, fields="price")
#       5 if isinstance(symbol, list):
#       6     prices.columns = map(lambda x: x.symbol, prices.columns)
#
# NameError: name 'get_pricing' is not defined
